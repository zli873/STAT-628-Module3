# %%
import os
os.environ["PROJ_LIB"] = "/Users/cainaiqing/anaconda3/share/proj"; #fixr
from mpl_toolkits.basemap import Basemap

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import seaborn as sns 
import matplotlib.gridspec as gridspec 
import matplotlib.gridspec as gridspec

# %%
import plotly.offline as pyo
from plotly.graph_objs import *
import plotly.graph_objs as go
#map section
import imageio
import folium
import folium.plugins as plugins
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
import json
from tqdm import tqdm
import operator

# %%
#read america_new_tip
america_new_tip = pd.read_csv('american_new_tip.csv')  
america_new_tip.head()

# %%
#make wordcloud
cloud = WordCloud(width=1440, height= 1080,max_words= 1000).generate(' '.join(america_new_tip['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off');

# %%
img = Image.open('yelp.png')
img
img_array = np.array(img)

# %%
yelp= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)

# %%
yelp.generate(' '.join(america_new_tip['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp)
plt.axis('off');

# %%
#read business
american_traditional_business = pd.read_csv('american_traditional_business.csv')
american_new_business = pd.read_csv('american_new_business.csv')

# %%
#Get the distribution of business ratings
star=american_traditional_business['stars'].value_counts()
star=star.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star.index, star.values, alpha=0.8)
plt.title("Star Rating Distribution of American Traditional Business")
plt.ylabel('Number of Businesses', fontsize=12)
plt.xlabel('Star Ratings ', fontsize=12)

#adding the text labels
rects = ax.patches
labels = star.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#read review
american_traditional_review = pd.read_csv('american_traditional_review.csv')
american_new_review = pd.read_csv('american_new_review.csv')
american_new_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 0               11  -I5umRTkhw15RqpKMl_o1Q  -mA3-1mN4JIEkqOtdbNXCQ
# 1               35  wOv7JiO0EGcJ61P2JcDS1g  en0xQXlvRk-ZtKlaW4I8eQ
# 2               36  RLbWoIri29BcQ8yjzsvQLQ  _o740mSNRhMNYuPjSJoPLg
# 3               37  JIC8qNMbcAPAzQMPrtsTJw  fxrQSMhHlBv6eJVRdchG9Q
# 4               43  j3vP8537KHvoXNHQIr3haA  Z_HE_KKT7N-WddPTzUQC7A
# 5               44  f0B9-r14-bLudyu5S7aLhw  SvMGr_Oih7ivtzmnCL-Tmg
# 6               46  vzMkIQm34QWBCYaHdV-2mQ  jAVtSgE5L-Dt6_I5FIiVGA
# 7               48  u1jQX0KfnG3AHty4ifEpFA  8vIK6ndl8yzIdmSDnGp0tw
# 8               56  VqZMgUf4wQMTeCWg2M_e8Q  POr1NTWV45OaNCOLfb47fw
# 9               67  XAm4_-lUxzF_Y449cWMHLQ  ABUt9wCHRsSpa8i7rtNAuQ
# 10              68  dcKpWjwqKl0ImVKEru6Q1A  X-5IICsYwqImns4WxHi91Q
# 11              82  m2H0m3pDUNmkXZP4K8c_oA  fVK8D0rE9ez1fsQNW_bzRA
# 12              83  JYdhCDyR6lYfN2qnSspLlQ  6kEFHccntnYMF_7cdqCcKg
values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Global view of Yelp businesses

#basic basemap of the world
plt.figure(1, figsize=(15,6))
# use ortho projection for the globe type version
m1=Basemap(projection='ortho',lat_0=20,lon_0=-50)

#hex codes from google maps color pallete = http://www.color-hex.com/color-palette/9261
#add continents
m1.fillcontinents(color='#bbdaa4',lake_color='#4a80f5') 
#add the oceans
m1.drawmapboundary(fill_color='#4a80f5')                
#Draw the boundaries of the countires
m1.drawcountries(linewidth=0.1, color="black")

#Add the scatter points to indicate the locations of the businesses
mxy = m1(american_traditional_business["longitude"].tolist(), american_traditional_business["latitude"].tolist())
m1.scatter(mxy[0], mxy[1], s=1, c="yellow", lw=0.1, alpha=1, zorder=5)
plt.title("World-wide Yelp American Traditional Business Distribution")
plt.show()

# %%
#Global view of Yelp businesses

#basic basemap of the world
plt.figure(1, figsize=(15,6))
# use ortho projection for the globe type version
m2=Basemap(projection='ortho',lat_0=20,lon_0=-50)

#hex codes from google maps color pallete = http://www.color-hex.com/color-palette/9261
#add continents
m2.fillcontinents(color='#bbdaa4',lake_color='#4a80f5') 
#add the oceans
m2.drawmapboundary(fill_color='#4a80f5')                
#Draw the boundaries of the countires
m2.drawcountries(linewidth=0.1, color="black")

#Add the scatter points to indicate the locations of the businesses
mxy2 = m2(american_new_business["longitude"].tolist(), american_new_business["latitude"].tolist())
m2.scatter(mxy2[0], mxy2[1], s=1, c="yellow", lw=0.1, alpha=1, zorder=5)
plt.title("World-wide Yelp American New Business Distribution")
plt.show()

# %%
def json_get_length(path):
    with open(path, encoding="utf-8") as f:
        lines = f.readlines()
        return len(lines)

# %%
def json_to_df(path, l):
    with open(path, encoding="utf-8") as f:
        dic = {}
        for i in tqdm(range(l)):
            line = f.readline()
            dic_new = dict(json.loads(line))
            if i == 0:
                dic = dic_new
                for key in dic:
                    dic[key] = [dic[key]]
            else:
                for key in dic:
                    dic[key].append(dic_new[key])
        f.close()
        dic = pd.DataFrame(dic)
        return dic

# %%
#read business file
l_business=json_get_length('business.json')
business = json_to_df('business.json',l_business)
business.head()

# %%
#read review file
l_review=json_get_length('review.json')
review = json_to_df('review.json',l_review)
review.head()
# Out:
# 100%|██████████| 6685900/6685900 [05:13<00:00, 21338.62it/s]

# %%
unique_business_id = set(list(review['business_id']))

# %%
#find information only for these business
business = business[business['business_id'].isin(unique_business_id)]
business_categories=business['categories']

# %%
#restaurant business categories
business.index = range(len(business))
restaurant = []
categories_count = {}
for i in tqdm(range(len(business))):
    if business.loc[i, 'categories']:
        if "Restaurants" in business.loc[i, 'categories']:
            restaurant.append(i)
            curr = business.loc[i, 'categories'].split(',')
            for e in curr:
                categories_count[e] = categories_count.get(e, 0)+1
# Out:
# 100%|██████████| 192606/192606 [00:09<00:00, 19744.59it/s]

# %%
sorted_cat = sorted(categories_count.items(),key = operator.itemgetter(1))
sorted_cat=sorted_cat[::-1][1:20]
sorted_cat
# Out:
# [('Restaurants', 17948),
#  (' Food', 11956),
#  (' Nightlife', 7133),
#  (' Bars', 6888),
#  (' American (Traditional)', 5542),
#  (' Sandwiches', 5524),
#  (' Fast Food', 5320),
#  (' Pizza', 4658),
#  (' Breakfast & Brunch', 4231),
#  (' Burgers', 4138),
#  (' American (New)', 3790),
#  (' Italian', 3381),
#  (' Coffee & Tea', 3041),
#  (' Mexican', 3033),
#  (' Chinese', 2867),
#  ('Food', 2844),
#  (' Cafes', 2561),
#  (' Event Planning & Services', 2277),
#  ('Pizza', 2146)]

# %%
from pandas.core.frame import DataFrame
cat_df=DataFrame(sorted_cat)
dic = {'cat_name': cat_df[0], 'cat_count':cat_df[1]}
cat_df=DataFrame(dic)

# %%
plt.subplots(figsize=(8, 8))
labels=cat_df['cat_name']
cat_df['cat_count'].plot.bar( align='center', alpha=0.5)
y_pos = np.arange(len(labels))
#plt.yticks(y_pos, labels)
plt.xticks(y_pos, labels)
plt.xlabel('Restaurant Business Categories')
plt.ylabel('Categories Count')
plt.show()

# %%
#whole business categories
business.index = range(len(business))
whole_categories_count = {}
for i in tqdm(range(len(business))):
    if business.loc[i, 'categories']:
        curr = business.loc[i, 'categories'].split(',')
        for e in curr:
            whole_categories_count[e] = whole_categories_count.get(e, 0)+1
# Out:
# 100%|██████████| 192606/192606 [00:07<00:00, 24542.80it/s]

# %%
whole_sorted_cat = sorted(whole_categories_count.items(),key = operator.itemgetter(1))
whole_sorted_cat=whole_sorted_cat[::-1][0:20]
whole_sorted_cat
# Out:
# [(' Restaurants', 41423),
#  (' Shopping', 24086),
#  (' Food', 21966),
#  ('Restaurants', 17948),
#  (' Home Services', 14462),
#  (' Beauty & Spas', 13538),
#  (' Health & Medical', 12601),
#  (' Local Services', 10519),
#  (' Nightlife', 10382),
#  (' Bars', 9209),
#  (' Automotive', 9073),
#  (' Event Planning & Services', 8144),
#  ('Food', 8022),
#  ('Shopping', 7790),
#  (' Active Life', 7202),
#  (' Fashion', 6154),
#  ('Beauty & Spas', 5832),
#  (' American (Traditional)', 5542),
#  (' Sandwiches', 5524),
#  (' Coffee & Tea', 5344)]

# %%
from pandas.core.frame import DataFrame
whole_cat_df=DataFrame(whole_sorted_cat)
dic = {'cat_name': whole_cat_df[0], 'cat_count':whole_cat_df[1]}
whole_cat_df=DataFrame(dic)
# Out:
#                       cat_name  cat_count
# 0                  Restaurants      41423
# 1                     Shopping      24086
# 2                         Food      21966
# 3                  Restaurants      17948
# 4                Home Services      14462
# 5                Beauty & Spas      13538
# 6             Health & Medical      12601
# 7               Local Services      10519
# 8                    Nightlife      10382
# 9                         Bars       9209
# 10                  Automotive       9073
# 11   Event Planning & Services       8144
# 12                        Food       8022
# 13                    Shopping       7790
# 14                 Active Life       7202
# 15                     Fashion       6154
# 16               Beauty & Spas       5832
# 17      American (Traditional)       5542
# 18                  Sandwiches       5524
# 19                Coffee & Tea       5344

# %%
plt.subplots(figsize=(8, 8))
labels=whole_cat_df['cat_name']
whole_cat_df['cat_count'].plot.bar( align='center', alpha=0.5)
y_pos = np.arange(len(labels))
#plt.yticks(y_pos, labels)
plt.xticks(y_pos, labels)
plt.xlabel('Business Categories')
plt.ylabel('Categories Count')
plt.show()
