# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def calculate_coherence( w2v_model, term_rankings ):
    overall_coherence = 0.0
    for topic_index in range(len(term_rankings)):
        # check each pair of terms
        pair_scores = []
        for pair in combinations( term_rankings[topic_index], 2 ):
            pair_scores.append( w2v_model.similarity(pair[0], pair[1]) )
        # get the mean for all pairs in this topic
        topic_score = sum(pair_scores) / len(pair_scores)
        overall_coherence += topic_score
    # get the mean score across all topics
    return overall_coherence / len(term_rankings)

import numpy as np
def get_descriptor( all_terms, H, topic_index, top ):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    # now get the terms corresponding to the top-ranked indices
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append( all_terms[term_index] )
    return top_terms

def rank_terms( A, terms ):
    # get the sums over each column
    sums = A.sum(axis=0)
    # map weights to the terms
    weights = {}
    for col, term in enumerate(terms):
        weights[term] = sums[0,col]
    # rank the terms by their weight over all documents
    return sorted(weights.items(), key=operator.itemgetter(1), reverse=True)

# %%
import pandas as pd
import string

custom_stop_words = []
with open( '/content/drive/My Drive/STAT628_Module3/Data Preprocessing/feature extraction/stopwords.txt', "r" ) as fin:
    for line in fin.readlines():
        custom_stop_words.append( line.strip() )
# note that we need to make it hashable
print("Stopword list has %d entries" % len(custom_stop_words) )

city_list = ['ON','AZ','IL','NC','NV','OH','AB','PA','QC','SC','WI']
for city in city_list:
  print('\n======================= Analysis for',city,'==============================')
  path = '/content/drive/My Drive/STAT628_Module3/Score Model/bars_review_' + city +'.csv'

  df = pd.read_csv(path)
  df = df.loc[df['text']!='']

  # df_pos = df.loc[df['stars']>=5.0]
  df_neg = df.loc[df['stars']<=2.0]

  import numpy as np
  from sklearn.feature_extraction.text import CountVectorizer
  vectorizer = CountVectorizer(stop_words = custom_stop_words, min_df = 20)
  A_neg = vectorizer.fit_transform(df_neg['text'].apply(lambda x: np.str_(x)))
  terms_neg = vectorizer.get_feature_names()
  print("negative vocabulary has %d distinct terms" % len(terms_neg))
  print( "Created %d X %d negative document-term matrix" % (A_neg.shape[0], A_neg.shape[1]) )

  raw_documents_neg = list(df_neg['text'])
  from sklearn.externals import joblib
  joblib.dump((A_neg,terms_neg,raw_documents_neg), "articles-raw_neg.pkl") 

  import operator

  
  print('\nrank for negative words in',city,':')
  ranking = rank_terms( A_neg, terms_neg )
  for i, pair in enumerate( ranking[0:10] ):
      print( "%02d. %s (%.2f)" % ( i+1, pair[0], pair[1] ) )

 
  best_k = {'AB':5,'AZ':5,'IL':4,'NC':4,'NV':5,'OH':4,'ON':5,'PA':4,'QC':3,'SC':5,'WI':4}

  k = best_k[city]

  from sklearn import decomposition
  model = decomposition.NMF( init="nndsvd", n_components=k ) 
  # apply the model and extract the two factor matrices
  W_neg = model.fit_transform( A_neg )
  H_neg = model.components_

  print('\ndescriptors for negative texts in',city,':')
  descriptors = []
  for topic_index in range(k):
      descriptors.append( get_descriptor( terms_neg, H_neg, topic_index, 7 ) )
      str_descriptor = ", ".join( descriptors[topic_index] )
      print("Topic %02d: %s" % ( topic_index+1, str_descriptor ) )

  import collections
  ids = list(df_neg['business_id'])
  weights = list(df_neg['weight'])
  texts = list(df_neg['text'])
  busi_weight = collections.defaultdict(list)
  busi_text = collections.defaultdict(list)

  for i in range(len(ids)):
    if texts[i] is np.nan:
      continue
    busi = ids[i]
    busi_weight[busi].append(weights[i])
    busi_text[busi].append(texts[i])
    
  scores = []
  ids = []

  for busi in busi_text:
    ids.append(busi)
    if len(busi_text[busi]) < k:
      score = np.array([[0]*k])
      scores.append(score)
      continue
    A = vectorizer.transform(busi_text[busi])
    W = model.fit_transform( A )
    w = np.array([busi_weight[busi]])
    score = np.dot(w,W)
    score = score/sum(busi_weight[busi])
    scores.append(score)
  scores = np.array(scores)
  result = pd.DataFrame({'business_id':ids})
  word_weight = pd.DataFrame()

  top_terms = []
  top_weights = []
  for i in range(k):
    top_terms.append([])
    top_weights.append([])

    col_name = 'topic_'+str(i+1)
    result[col_name] = scores[:,0,i]



    topic_index = i
    top_indices = np.argsort( H_neg[topic_index,:] )[::-1]
    
    for term_index in top_indices[0:7]:
        top_terms[i].append( terms_neg[term_index] )
        top_weights[i].append( H_neg[topic_index,term_index] )
    print(top_terms[i])
    print(top_weights[i])

    col_name = 'topic_'+str(i+1)+'words'
    word_weight[col_name] = top_terms[i]
    col_name = 'topic_'+str(i+1)+'weight'
    word_weight[col_name] = top_weights[i]

  path = '/content/drive/My Drive/STAT628_Module3/score/'+city+'.csv'
  result.to_csv(path,index=False,sep=',')
  
  path = '/content/drive/My Drive/STAT628_Module3/word weight/'+city+'_weight.csv'
  word_weight.to_csv(path,index=False,sep=',')
# Out:
# Stopword list has 403 entries
#
# ======================= Analysis for ON ==============================
# negative vocabulary has 3880 distinct terms
# Created 20549 X 3880 negative document-term matrix
#
# rank for negative words in ON :
# 01. service (13072.00)
# 02. time (11074.00)
# 03. drink (9501.00)
# 04. table (9343.00)
# 05. ask (8690.00)
# 06. wait (7510.00)
# 07. bar (6267.00)
# 08. server (6119.00)
# 09. tell (5750.00)
# 10. look (5577.00)
#
# descriptors for negative texts in ON :
# Topic 01: table, wait, seat, minutes, sit, host, arrive
# Topic 02: fry, taste, chicken, dish, menu, wing, sauce
# Topic 03: drink, bar, beer, night, look, friends, bartender
# Topic 04: time, service, wait, experience, staff, slow, long
# Topic 05: ask, server, tell, bill, manager, leave, waitress
# ['table', 'wait', 'seat', 'minutes', 'sit', 'host', 'arrive']
# [12.029219988805197, 6.56423725191533, 3.4299963071125026, 3.103288971586179, 2.0644827897548956, 1.8424517120324186, 1.40855295820922]
# ['fry', 'taste', 'chicken', 'dish', 'menu', 'wing', 'sauce']
# [3.886273234508964, 3.7615946757712337, 3.6816371418027845, 2.787331949903667, 2.694912823431482, 2.539565238843168, 2.378632587585898]
# ['drink', 'bar', 'beer', 'night', 'look', 'friends', 'bartender']
# [9.925584313729578, 6.193352502779196, 1.8463839447341046, 1.797890082127952, 1.2992181444717361, 1.2258708002878815, 1.1001076861648957]
# ['time', 'service', 'wait', 'experience', 'staff', 'slow', 'long']
# [8.688097181140222, 8.059445982256756, 1.5113239793005875, 1.3371025028327321, 1.0792993337771866, 0.9355579581137005, 0.8909952932290797]
# ['ask', 'server', 'tell', 'bill', 'manager', 'leave', 'waitress']
# [8.505694349737396, 4.254018569016838, 4.170431999709228, 3.4046692672569736, 2.4429421025850595, 2.1033423865263083, 1.967700349759681]
#
# ======================= Analysis for AZ ==============================
# negative vocabulary has 6093 distinct terms
# Created 56549 X 6093 negative document-term matrix
#
# rank for negative words in AZ :
# 01. service (32680.00)
# 02. time (32030.00)
# 03. drink (25281.00)
# 04. ask (24203.00)
# 05. table (22773.00)
# 06. wait (21479.00)
# 07. bar (20064.00)
# 08. minutes (17936.00)
# 09. tell (16278.00)
# 10. server (14661.00)
#
# descriptors for negative texts in AZ :
# Topic 01: table, wait, minutes, seat, sit, server, host
# Topic 02: taste, chicken, fry, cheese, menu, look, salad
# Topic 03: drink, bar, bartender, sit, night, beer, look
# Topic 04: time, service, experience, customer, location, staff, long
# Topic 05: ask, tell, manager, server, leave, know, waitress
# ['table', 'wait', 'minutes', 'seat', 'sit', 'server', 'host']
# [12.732662328537513, 10.01760209157445, 7.035839406935826, 4.082073723936217, 3.7614486115233086, 2.675251462741158, 2.437538937097805]
# ['taste', 'chicken', 'fry', 'cheese', 'menu', 'look', 'salad']
# [3.965141677145462, 3.5647880448400535, 3.087956732873626, 2.880676199516193, 2.8521653482325324, 2.8031055629966146, 2.4727351693851682]
# ['drink', 'bar', 'bartender', 'sit', 'night', 'beer', 'look']
# [11.334464019690296, 10.308869961734406, 2.762453402662654, 2.1691332262317093, 1.6685336942413713, 1.6599830665192516, 1.5784274987605675]
# ['time', 'service', 'experience', 'customer', 'location', 'staff', 'long']
# [13.326302612167936, 9.305612148961831, 1.3107094745261036, 1.3000602256236282, 1.072511519349389, 1.0069244446159094, 0.9666034370117564]
# ['ask', 'tell', 'manager', 'server', 'leave', 'know', 'waitress']
# [11.560398843113264, 6.732103491984789, 4.783451092515415, 2.6024584346192166, 2.3983021293919853, 2.3463750669270107, 2.2541825592810296]
#
# ======================= Analysis for IL ==============================
# negative vocabulary has 519 distinct terms
# Created 1142 X 519 negative document-term matrix
#
# rank for negative words in IL :
# 01. time (679.00)
# 02. service (592.00)
# 03. drink (502.00)
# 04. table (488.00)
# 05. bar (473.00)
# 06. ask (437.00)
# 07. wait (415.00)
# 08. minutes (385.00)
# 09. waitress (304.00)
# 10. look (288.00)
#
# descriptors for negative texts in IL :
# Topic 01: time, wait, minutes, service, drink, waitress, seat
# Topic 02: chicken, taste, dish, menu, cheese, sauce, steak
# Topic 03: bar, drink, beer, sit, bartender, look, know
# Topic 04: table, ask, server, look, manager, tell, minutes
# ['time', 'wait', 'minutes', 'service', 'drink', 'waitress', 'seat']
# [4.820837441113593, 3.294404421789761, 2.8724932774970764, 2.7463601800284763, 1.584691946630672, 1.2888772649838303, 0.9707940382390702]
# ['chicken', 'taste', 'dish', 'menu', 'cheese', 'sauce', 'steak']
# [1.84058200268952, 1.7313887871468872, 1.5763253233439165, 1.3543458177427043, 1.349968149731622, 1.182269481541956, 1.156660466611691]
# ['bar', 'drink', 'beer', 'sit', 'bartender', 'look', 'know']
# [4.396158625807742, 2.779258589727651, 1.4228762928106033, 0.6884530558001593, 0.6824131755318503, 0.6239805701118863, 0.5940797981677136]
# ['table', 'ask', 'server', 'look', 'manager', 'tell', 'minutes']
# [3.455721685199908, 3.265855906328937, 1.9035842982349798, 1.4256506191688716, 1.0414841318852595, 0.8845845636524874, 0.8824479207963749]
#
# ======================= Analysis for NC ==============================
# negative vocabulary has 2865 distinct terms
# Created 14822 X 2865 negative document-term matrix
#
# rank for negative words in NC :
# 01. time (8602.00)
# 02. service (8168.00)
# 03. drink (6643.00)
# 04. wait (6183.00)
# 05. ask (6092.00)
# 06. table (5976.00)
# 07. bar (5122.00)
# 08. minutes (5051.00)
# 09. tell (4231.00)
# 10. server (3691.00)
#
# descriptors for negative texts in NC :
# Topic 01: table, wait, minutes, ask, server, tell, seat
# Topic 02: chicken, fry, taste, cheese, menu, sauce, salad
# Topic 03: drink, bar, bartender, ask, beer, sit, service
# Topic 04: time, service, experience, staff, customer, location, movie
# ['table', 'wait', 'minutes', 'ask', 'server', 'tell', 'seat']
# [7.445627156954906, 6.564566687998013, 6.004822880693908, 4.48071629312563, 3.25096685843462, 3.249380952915002, 2.9960345652141434]
# ['chicken', 'fry', 'taste', 'cheese', 'menu', 'sauce', 'salad']
# [2.8922890290299623, 2.851717651370884, 2.4773112266895594, 2.2943375201797456, 2.08846242777951, 1.9441486934270513, 1.9401761481336561]
# ['drink', 'bar', 'bartender', 'ask', 'beer', 'sit', 'service']
# [9.443054409201448, 6.2235596770787565, 1.8015848595180592, 1.6244010358364467, 1.479972696144689, 1.2640006240819666, 1.157439054980462]
# ['time', 'service', 'experience', 'staff', 'customer', 'location', 'movie']
# [10.209197647016076, 4.975444506264576, 1.0604347432029897, 0.915076099780174, 0.8586226287694483, 0.7587926623959795, 0.7390604064451204]
#
# ======================= Analysis for NV ==============================
# negative vocabulary has 7033 distinct terms
# Created 64054 X 7033 negative document-term matrix
#
# rank for negative words in NV :
# 01. service (36411.00)
# 02. time (34124.00)
# 03. drink (30399.00)
# 04. ask (26589.00)
# 05. wait (22685.00)
# 06. table (22588.00)
# 07. tell (21243.00)
# 08. bar (20150.00)
# 09. minutes (17453.00)
# 10. room (16012.00)
#
# descriptors for negative texts in NV :
# Topic 01: table, ask, wait, minutes, service, tell, server
# Topic 02: room, hotel, stay, call, check, tell, desk
# Topic 03: drink, bar, bartender, sit, ask, service, look
# Topic 04: taste, fry, burger, service, chicken, menu, steak
# Topic 05: time, club, tell, night, line, vegas, pay
# ['table', 'ask', 'wait', 'minutes', 'service', 'tell', 'server']
# [10.195355558143854, 8.911124354609074, 8.6562691876118, 6.8434704167755935, 5.54765818950293, 4.903599160414269, 4.212664111318167]
# ['room', 'hotel', 'stay', 'call', 'check', 'tell', 'desk']
# [13.264693599885407, 5.869887468415152, 4.695292675632398, 3.0388088820462733, 2.8035951154631973, 2.508119055386392, 2.333283281031143]
# ['drink', 'bar', 'bartender', 'sit', 'ask', 'service', 'look']
# [14.481711670690595, 8.536059604278265, 3.1324159452506923, 1.876660927050022, 1.4802845586594475, 1.3068847816797329, 1.19463871132925]
# ['taste', 'fry', 'burger', 'service', 'chicken', 'menu', 'steak']
# [4.052086264418856, 3.3145757463597465, 3.039238762147877, 2.973359763833617, 2.913136277556244, 2.6795282668108102, 2.509378795954162]
# ['time', 'club', 'tell', 'night', 'line', 'vegas', 'pay']
# [11.075636535287764, 3.9137315634826404, 2.489211551150947, 2.3102160750807808, 2.2512716990270674, 2.105210216004369, 1.974651568672108]
#
# ======================= Analysis for OH ==============================
# negative vocabulary has 2835 distinct terms
# Created 14255 X 2835 negative document-term matrix
#
# rank for negative words in OH :
# 01. time (7391.00)
# 02. service (7373.00)
# 03. drink (6483.00)
# 04. bar (5866.00)
# 05. table (5577.00)
# 06. wait (5423.00)
# 07. ask (5109.00)
# 08. minutes (4343.00)
# 09. tell (3787.00)
# 10. server (3466.00)
#
# descriptors for negative texts in OH :
# Topic 01: table, wait, minutes, ask, tell, server, seat
# Topic 02: taste, chicken, fry, menu, cheese, sauce, look
# Topic 03: bar, drink, bartender, sit, beer, service, night
# Topic 04: time, service, experience, call, manager, slow, tell
# ['table', 'wait', 'minutes', 'ask', 'tell', 'server', 'seat']
# [7.773111930048985, 6.7260913739499255, 5.031659753277795, 4.1110010786878375, 3.046567956067183, 2.9654729112131264, 2.953198955023885]
# ['taste', 'chicken', 'fry', 'menu', 'cheese', 'sauce', 'look']
# [2.786855776843319, 2.6457916317298937, 2.523362831144986, 2.396940173038569, 2.3630736762335314, 2.0804475430322102, 1.992985675334136]
# ['bar', 'drink', 'bartender', 'sit', 'beer', 'service', 'night']
# [7.979515572939252, 7.198501795400091, 1.997257364079425, 1.6965786091982882, 1.6106288730400808, 1.1157218326378362, 1.0641621928247371]
# ['time', 'service', 'experience', 'call', 'manager', 'slow', 'tell']
# [9.334918204226495, 5.038014461094677, 1.0412245791514494, 0.799104128469688, 0.745811923179645, 0.729136343382976, 0.6887991858043783]
#
# ======================= Analysis for AB ==============================
# negative vocabulary has 1096 distinct terms
# Created 2945 X 1096 negative document-term matrix
#
# rank for negative words in AB :
# 01. service (1847.00)
# 02. time (1624.00)
# 03. drink (1460.00)
# 04. table (1277.00)
# 05. ask (1163.00)
# 06. server (1108.00)
# 07. wait (963.00)
# 08. waitress (833.00)
# 09. bar (795.00)
# 10. minutes (729.00)
#
# descriptors for negative texts in AB :
# Topic 01: table, ask, server, wait, drink, minutes, tell
# Topic 02: menu, steak, salad, look, taste, chicken, fry
# Topic 03: wing, night, chicken, drink, hot, sauce, server
# Topic 04: bar, beer, drink, pub, look, pay, music
# Topic 05: time, service, server, wait, experience, staff, slow
# ['table', 'ask', 'server', 'wait', 'drink', 'minutes', 'tell']
# [5.20650468968756, 3.6072437345299173, 2.9559493659218883, 2.7613569716699065, 2.734688457896832, 2.1724590404719133, 2.068756110492048]
# ['menu', 'steak', 'salad', 'look', 'taste', 'chicken', 'fry']
# [2.042692593348469, 1.9544296359128281, 1.7961555553153987, 1.6871095540548515, 1.5733299431210046, 1.4649517945546848, 1.351090371646875]
# ['wing', 'night', 'chicken', 'drink', 'hot', 'sauce', 'server']
# [6.813792565072276, 1.2966721481734207, 0.6694003968523247, 0.5949587048889791, 0.5366300906046509, 0.5362702638951365, 0.4589459019060375]
# ['bar', 'beer', 'drink', 'pub', 'look', 'pay', 'music']
# [4.28472936437025, 3.091922659442322, 2.6483160188481505, 1.102595090294856, 0.7395112224115554, 0.7203199205157053, 0.6629544193331307]
# ['time', 'service', 'server', 'wait', 'experience', 'staff', 'slow']
# [5.113380833900338, 4.946269472230739, 1.0483548212730966, 0.7343819805889628, 0.6206550080649345, 0.6186185943017781, 0.5474491994440747]
#
# ======================= Analysis for PA ==============================
# negative vocabulary has 2665 distinct terms
# Created 11655 X 2665 negative document-term matrix
#
# rank for negative words in PA :
# 01. time (6080.00)
# 02. service (5561.00)
# 03. drink (5128.00)
# 04. bar (4716.00)
# 05. table (4562.00)
# 06. wait (4290.00)
# 07. ask (4100.00)
# 08. minutes (3377.00)
# 09. tell (2996.00)
# 10. waitress (2741.00)
#
# descriptors for negative texts in PA :
# Topic 01: table, wait, minutes, ask, waitress, tell, seat
# Topic 02: fry, sandwich, taste, burger, cheese, menu, chicken
# Topic 03: bar, drink, bartender, beer, service, sit, night
# Topic 04: time, service, experience, manager, server, tell, know
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/nmf.py:361: RuntimeWarning: invalid value encountered in true_divide
#   u = x_n / x_n_nrm
# /usr/local/lib/python3.6/dist-packages/sklearn/decomposition/nmf.py:369: RuntimeWarning: invalid value encountered in less
#   W[W < eps] = 0
# ['table', 'wait', 'minutes', 'ask', 'waitress', 'tell', 'seat']
# [7.318160212777609, 6.457447135749204, 4.810949325220429, 3.8054618949453496, 2.82873058848509, 2.7932379102160283, 2.506140967935145]
# ['fry', 'sandwich', 'taste', 'burger', 'cheese', 'menu', 'chicken']
# [3.849334795635559, 3.550248626824093, 2.7956578427793786, 2.5608384101037633, 2.5045824082052612, 2.0796452834139636, 1.9337875757559435]
# ['bar', 'drink', 'bartender', 'beer', 'service', 'sit', 'night']
# [7.581956893037111, 6.441183898360244, 2.048673854720156, 1.6886663407989444, 1.3173827302846384, 1.3015766517479403, 1.057199939604537]
# ['time', 'service', 'experience', 'manager', 'server', 'tell', 'know']
# [8.758037909324889, 3.2959364118089276, 1.1040897096292457, 0.9857368495385314, 0.9106587688215748, 0.8308251892007342, 0.7823895271651884]
#
# ======================= Analysis for QC ==============================
# negative vocabulary has 1105 distinct terms
# Created 3519 X 1105 negative document-term matrix
#
# rank for negative words in QC :
# 01. service (1841.00)
# 02. drink (1696.00)
# 03. time (1374.00)
# 04. bar (1152.00)
# 05. ask (1139.00)
# 06. table (1094.00)
# 07. wait (1020.00)
# 08. leave (788.00)
# 09. waitress (777.00)
# 10. tell (756.00)
#
# descriptors for negative texts in QC :
# Topic 01: table, ask, wait, time, service, minutes, waitress
# Topic 02: drink, bar, night, beer, bartender, pay, leave
# Topic 03: fry, menu, taste, dish, service, burger, chicken
# ['table', 'ask', 'wait', 'time', 'service', 'minutes', 'waitress']
# [4.1478638500663925, 3.7123941518972683, 3.512653664663817, 2.9625549694127375, 2.9233451076159356, 2.719095921974759, 2.418670807827672]
# ['drink', 'bar', 'night', 'beer', 'bartender', 'pay', 'leave']
# [6.770194944936116, 4.081436426497038, 1.185688909038165, 1.0263220821061436, 0.9742438826886441, 0.9246280175900985, 0.8473853987596388]
# ['fry', 'menu', 'taste', 'dish', 'service', 'burger', 'chicken']
# [2.1150738391714725, 1.8064062710505828, 1.6620286220413383, 1.6007017380264414, 1.4809175103454193, 1.4680119427460674, 1.396038275452145]
#
# ======================= Analysis for SC ==============================
# negative vocabulary has 297 distinct terms
# Created 716 X 297 negative document-term matrix
#
# rank for negative words in SC :
# 01. time (430.00)
# 02. service (380.00)
# 03. table (285.00)
# 04. wait (282.00)
# 05. drink (279.00)
# 06. minutes (257.00)
# 07. ask (251.00)
# 08. bar (249.00)
# 09. sit (220.00)
# 10. waitress (202.00)
#
# descriptors for negative texts in SC :
# Topic 01: table, server, time, ask, sit, clean, minutes
# Topic 02: time, burger, experience, wife, review, half, know
# Topic 03: bar, service, staff, sit, time, manager, bartender
# Topic 04: wait, minutes, drink, waitress, ask, tell, manager
# Topic 05: chicken, fry, service, wing, taste, sauce, look
# ['table', 'server', 'time', 'ask', 'sit', 'clean', 'minutes']
# [5.234150088115737, 1.7794764538339078, 1.3988039109443025, 1.16467385219888, 0.9422320064179416, 0.8332831201279479, 0.8320027746352543]
# ['time', 'burger', 'experience', 'wife', 'review', 'half', 'know']
# [3.3075245843312167, 2.7323968487804646, 1.2271960046187917, 0.996142646173854, 0.898669624029932, 0.7026695020500322, 0.5500517802143868]
# ['bar', 'service', 'staff', 'sit', 'time', 'manager', 'bartender']
# [3.841722099728934, 1.9429409756588987, 1.288744686104858, 1.14688194028914, 0.9087676573285015, 0.8685676459241866, 0.683077146322426]
# ['wait', 'minutes', 'drink', 'waitress', 'ask', 'tell', 'manager']
# [2.9856673929718225, 2.237042065153877, 2.205653311936358, 1.8309123780026173, 1.7192066490108322, 1.5192382051166173, 0.9413083279605972]
# ['chicken', 'fry', 'service', 'wing', 'taste', 'sauce', 'look']
# [1.5810202163701048, 1.356449507430719, 1.2865747350688452, 1.2187139779717409, 0.9808975267603293, 0.9736556532241762, 0.9383480147042411]
#
# ======================= Analysis for WI ==============================
# negative vocabulary has 1650 distinct terms
# Created 5206 X 1650 negative document-term matrix
#
# rank for negative words in WI :
# 01. time (2856.00)
# 02. service (2642.00)
# 03. drink (2482.00)
# 04. bar (2377.00)
# 05. table (2014.00)
# 06. wait (1856.00)
# 07. ask (1834.00)
# 08. minutes (1486.00)
# 09. fry (1334.00)
# 10. beer (1298.00)
#
# descriptors for negative texts in WI :
# Topic 01: table, wait, minutes, ask, drink, server, tell
# Topic 02: fry, cheese, menu, taste, burger, sauce, chicken
# Topic 03: bar, drink, bartender, beer, sit, look, night
# Topic 04: time, service, experience, staff, before, know, call
# ['table', 'wait', 'minutes', 'ask', 'drink', 'server', 'tell']
# [5.693344462846807, 4.80132371737641, 4.06556446517929, 3.469782120068125, 3.2867326042254796, 2.7182242189651786, 2.029698284066253]
# ['fry', 'cheese', 'menu', 'taste', 'burger', 'sauce', 'chicken']
# [3.0355210168250015, 2.6816121099007613, 2.4562213628721716, 2.0326816193951482, 1.8722960318400688, 1.6016184295342286, 1.5108147863171975]
# ['bar', 'drink', 'bartender', 'beer', 'sit', 'look', 'night']
# [7.052927737859449, 3.5183598615676295, 2.144567212400098, 1.6967105872187664, 0.9571973012564622, 0.909433932910869, 0.8876018378127675]
# ['time', 'service', 'experience', 'staff', 'before', 'know', 'call']
# [7.531150944501089, 3.3736825508786743, 0.879858345131851, 0.8239866081904339, 0.5560329103662789, 0.5424672817200196, 0.539421931942309]

# %%
  path = '/content/drive/My Drive/STAT628_Module3/Bars Review by States/bars_review_AB.csv'

  df = pd.read_csv(path)
  df = df.loc[df['text']!='']

  # df_pos = df.loc[df['stars']>=5.0]
  df_neg = df.loc[df['stars']<=1.0]

# %%
len(df_neg)
# Out:
# 1438

# %%
l = list(df_neg['text'])

# %%
for review in l:
  if 'wings' in review:
    print(review)
    break
# Out:
# long long time customer location obvious issuesowners r nice despite request do wingsnot forget wifi place include nyc la wifi owners paranoid
