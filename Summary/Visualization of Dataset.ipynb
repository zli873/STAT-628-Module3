# %%
import os
os.environ["PROJ_LIB"] = "/Users/cainaiqing/anaconda3/share/proj"; #fixr
from mpl_toolkits.basemap import Basemap

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import seaborn as sns 
import matplotlib.gridspec as gridspec 
import matplotlib.gridspec as gridspec

# %%
import plotly.offline as pyo
from plotly.graph_objs import *
import plotly.graph_objs as go
#map section
import imageio
import folium
import folium.plugins as plugins
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
import json
from tqdm import tqdm
import operator

# %%
#read america_new_tip
america_new_tip = pd.read_csv('american_new_tip.csv')  
america_new_tip
# Out:
#        Unnamed: 0                 user_id             business_id  \
# 0              14  NEN5RFpZp7DE6K1PK2KZzg  Cni2l-VKG_pdospJ6xliXQ
# 1              17  3KkT6SmPFLGvBS1pnDBr8g  D2nfOrnJ2OBlX_428sKyMg
# 2              22  gGlFgp4nXNL5azpUtLK05w  cnfYugAYBFKgwDCTAVdViA
# 3              24  lesnCKZUYH554j-EDZBlTw  7sPNbCx7vGAaH7SbNPZ6oA
# 4              28  r64WY53LOMRPowHDu2JIXw  p-8AMN9Q0qwym-3Pdle20Q
# 5              30  8aXyfFUFrypoE6PkUQBtmg  PtwW1Hwme8Y0wy54zNr8Xw
# 6              35  ZK6aHHTiNlQWCCmv69OXnA  DkYS3arLOhA8si5uUEmHOw
# 7              65  AIHzJz0AvTq0FxCLtBhOZA  yNPh5SO-7wr8HPpVCDPbXQ
# 8              99  X0dnuT43dT-EyKOGgwN04w  XsSgv3vBOyOBXn3Co8EVIg
# 9             110  A69QAmKSdW45kUIqd4FESg  0NoHJtug9xefI2OnsANaMA
# 10            115  J7MsJKJDSA5OGo2-Hn7MbA  Q5sn7sP6v_lk3pxn0xVIlA
# 11            126  93z51tzHUp4ycmC45puYRg  h6Y1-KfN2XBkcrV85CS8yg
# 12            128  81pTE_HsEauWEMSZVQElbQ  zidkKI_N1OPxsiddTOQH_Q
# ...

# %%
america_traditional_tip = pd.read_csv('american_traditional_tip.csv') 
america_traditional_tip
# Out:
#         Unnamed: 0                 user_id             business_id  \
# 0                0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1                1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2               21  pDAqvfflIM4AM23VRpqAaw  0PVxodALQu-soL5J8bjerQ
# 3               34  2EuPAGalYnP7eSxPgFCNDg  NqCHqgF_FY0Aw9gD-Z3ABQ
# 4               38  CcJQAZfk6QkaBjPnKepLcg  vYn0gishV27DpfM_loZITQ
# 5               44  R_wlZO-jKFGEVJnSfWISqQ  Z15a7_8FQ82_baSJiqMoIw
# 6               51  330erZ8TCzA2eoexQMATBg  6sKaAF8WhWyyCjfZr2Rfsg
# 7               79  YB2SZbMgQHBOGOIsBK2Tkg  maIam6HyU4FB_sBIk9ippA
# 8              127  E3OfYM72qgnzJKRmAW0Fdw  oj8qk3W7O9oq15VIs-vYJQ
# 9              132  mRMoX1irrRhkd4w6na4dqg  VlDTUr3y-bdVZDKXEILKfQ
# 10             136  1BWCs7aXDg-EiLmv-U3qtw  6OkjUz-I552moryf3qN1Gg
# 11             139  mo-Xf9kSLvv9Qz8YGZRfqw  R3B_ibZvlrgzch_UkYQkrg
# 12             206  Ye80JpIGZEx1R1RrJLfkYg  Y6ERro4P_wmneOWj07n94A
# ...

# %%
#make wordcloud
cloud = WordCloud(width=1440, height= 1080,max_words= 1000).generate(' '.join(america_new_tip['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off');

# %%
img = Image.open('yelp.png')
img
img_array = np.array(img)

# %%
yelp1= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)

# %%
yelp1.generate(' '.join(america_new_tip['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp1)
plt.axis('off');

# %%
yelp2= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)
yelp2.generate(' '.join(america_traditional_tip['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp2)
plt.axis('off');

# %%
#read review
american_traditional_review = pd.read_csv('american_traditional_review.csv')

# %%
american_traditional_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 0               48  u1jQX0KfnG3AHty4ifEpFA  8vIK6ndl8yzIdmSDnGp0tw
# 1               53  7Jy730ib54YKYgZRvcBNJg  ROsjOYL8Jwv-q78mNm69Hg
# 2               56  VqZMgUf4wQMTeCWg2M_e8Q  POr1NTWV45OaNCOLfb47fw
# 3               72  QSe9EqmiImbguDVIraX_rg  II8eB5mYk200GW-m-wpsug
# 4               80  dS5ERxmIP-CQ_ZV_q_xc0A  SYRRQJoa5gQ8Duev4uSWag
# 5               85  29S2A-Q8Vt4a-Z6St1dcWw  J6YedGZVdhagKKaIqgzIAw
# 6               86  DmlGGWLHPAQl2v9qM5noyQ  8fpiTkK4MO5jJIXHFV4t5Q
# 7               94  LaSg1wlkosR6aSiuzxyo3A  9QoXklTk-Fl1Q1Cy8fCbdQ
# 8               98  kQAHUQ89fIZVCf1cFKDE_Q  dL1qnksdX2LW4DbNI9XNoA
# 9               99  jdDxglqBqPJPYQO5QlY8pA  2Klw_6aXH_aVcOXPiFHRzg
# 10             101  b5f0MzgbgUIcFy1yLueRGA  fX_E3GLT8iwc2M8Thy2wmA
# 11             125  P1SXso5nMKwhHyTW6OIIIg  OuRmjIT8yj8w04XsLX1tlg
# 12             128  _LPOtmfWnL_8_tL3ImhoLw  91DAiIKXri-41uzYue2hlg
# ...

# %%
review_bad=list(american_traditional_review['stars'])
review_bad=list(map(float, review_bad))
review_bad=list(map(int, review_bad))
review_bad
# Out:
# [4,
#  4,
#  3,
#  4,
#  5,
#  4,
#  1,
#  3,
#  4,
#  5,
#  4,
#  5,
#  5,
#  2,
#  3,
#  4,
#  3,
#  4,
#  2,
#  5,
#  2,
#  4,
#  4,
#  4,
#  3,
#  4,
#  1,
#  5,
#  3,
#  2,
#  2,
#  4,
#  5,
#  2,
#  5,
#  3,
#  5,
#  3,
#  2,
#  5,
#  5,
#  4,
#  4,
#  3,
#  3,
#  2,
#  5,
#  4,
#  5,
#  3,
#  2,
#  4,
#  5,
#  3,
#  4,
#  3,
#  5,
#  5,
#  2,
#  5,
#  4,
#  4,
#  1,
#  2,
#  1,
#  5,
#  5,
#  3,
#  5,
#  4,
#  3,
#  4,
#  5,
#  3,
#  5,
#  3,
#  2,
#  4,
#  3,
#  5,
#  4,
#  5,
#  4,
#  5,
#  2,
#  4,
#  4,
#  4,
#  4,
#  1,
#  3,
#  1,
#  2,
#  1,
#  5,
#  2,
#  4,
#  3,
#  5,
#  5,
#  3,
#  2,
#  4,
#  4,
#  5,
#  1,
#  2,
#  4,
#  5,
#  4,
#  1,
#  2,
#  1,
#  3,
#  5,
#  5,
#  4,
#  5,
#  5,
#  4,
#  2,
#  2,
#  5,
#  2,
#  3,
#  1,
#  1,
#  3,
#  1,
#  4,
#  3,
#  2,
#  4,
#  1,
#  1,
#  5,
#  4,
#  4,
#  1,
#  5,
#  2,
#  2,
#  4,
#  1,
#  1,
#  5,
#  5,
#  1,
#  3,
#  5,
#  1,
#  3,
#  5,
#  3,
#  5,
#  4,
#  3,
#  4,
#  5,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  2,
# ...

# %%
american_traditional_review['stars']=review_bad

# %%
american_traditional_review =american_traditional_review[american_traditional_review ['stars']<=3]

# %%
american_traditional_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 2               56  VqZMgUf4wQMTeCWg2M_e8Q  POr1NTWV45OaNCOLfb47fw
# 6               86  DmlGGWLHPAQl2v9qM5noyQ  8fpiTkK4MO5jJIXHFV4t5Q
# 7               94  LaSg1wlkosR6aSiuzxyo3A  9QoXklTk-Fl1Q1Cy8fCbdQ
# 13             140  niN5qW_M5Y0W0zQEcQcFig  n5E4KzRRGosdxNcdyyZztg
# 14             163  ImAnCO3PJXW9fhh7yEazrw  TcByPmEbsEQYJYT7IBKXdg
# 16             194  8ZLUN83zwoxM_SZ7NZlj2w  zH6racrZ7rUqqv_Qy6dZDQ
# 18             202  ZMaaowJgxQ0vnJNOPZUcWw  3HCP7V2hcRfCheqfbbABYA
# 20             246  3Qc49B7dA0ONmCxrn5iwCQ  2k8OVAPxlXHsA5X6EIoQpQ
# 24             289  UPQ79Rqc27mKXYGAMRZ6qg  NqY4ku6Zqdalaozxk0NQ8w
# 26             297  EAk4jcLyj2s9R5AnRMpfpA  2xMIuIFfxOsx9TQ2yAvxKA
# 28             308  JO1EOjDfMdvC2Vrw5P-Baw  xBcNPTcCigOS4We-4ZIHqw
# 29             311  QS77qtxJJiqcNHo02R7oQg  sRcV5rWNfJ9wbB2guzEd7w
# 30             317  97dHPjR0BEsjQk_cuGZthA  mRXpu2KtivTLGeYM_nSQOA
# ...

# %%
yelp_bad1= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)
yelp_bad1.generate(' '.join(american_traditional_review['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp_bad1)
plt.axis('off');

# %%
american_new_review = pd.read_csv('american_new_review.csv')

# %%
yelp_bad1= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)
yelp_bad1.generate(' '.join(american_traditional_review['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp_bad1)
plt.axis('off');

# %%
#read business
american_traditional_business = pd.read_csv('american_traditional_business.csv')
american_traditional_business
# Out:
#       Unnamed: 0             business_id  \
# 0             77  KFbUQ-RR2UOV62Ep7WnXHw
# 1            113  7aLkFEBnL1LJmQdcuaovuQ
# 2            115  qJeSjOMgWB3er3UXG33ZVw
# 3            120  0lFAD4CuWcQVl9u3-lRaCQ
# 4            157  U3kygJOTlTQFlfaZS7sQjA
# 5            198  4n81G-pmC3rfhmaPsbwYKg
# 6            216  iwGhazq9eP51PSerTrMrwg
# 7            294  hZj2HCiLae5-AxIp0im6lQ
# 8            387  JO5_Frcbp9J732VNn-I3Ew
# 9            396  _WyTVGIhZIqesE4DLrcTvA
# 10           454  GiTv0gFXtYFQAzCXnPvepQ
# 11           513  ZBE-H_aUlicix_9vUGQPIQ
# 12           529  h_ypoQ2rmwX8UGSmohsGiQ
# 13           534  yGMCl0vYigshkXiZFIDTNw
# 14           564  221yaXPE1zmJqDvBVM__tw
# 15           565  3KzzG6dw5aN9eIo3cGHaSA
# 16           584  RGK23CEkDfYHWtUbRhA-bQ
# 17           603  MDJqm5KN1hFWm4R2VtNIlw
# 18           612  BkIZ8UDA23qxnp_kR1Sv8Q
# 19           632  qxFVwTstR5BuFa4kY50akQ
# 20           687  JrrY4v21k7_qYxIidhi-aw
# 21           688  xomRWgUrcq2ESC6oBwrfbA
# ...

# %%
american_new_business = pd.read_csv('american_new_business.csv')
american_new_business
# Out:
#       Unnamed: 0             business_id                             name  \
# 0            156  jScBTQtdAt-8RshaiBEHgw                           Served
# 1            260  tWjfgVtTD5n01Cq9dFWGsA                             Cibo
# 2            387  JO5_Frcbp9J732VNn-I3Ew                   Steak ’n Shake
# 3            454  GiTv0gFXtYFQAzCXnPvepQ                          Chili's
# 4            540  p8u03IURLPg_5jYSY3OmMQ                       Farmer Boy
# 5            565  3KzzG6dw5aN9eIo3cGHaSA                   Steak ’n Shake
# 6            584  RGK23CEkDfYHWtUbRhA-bQ             The Turnhouse Grille
# 7            603  MDJqm5KN1hFWm4R2VtNIlw                     Waffle House
# 8            637  MYMoho8uONfkTvaVNL-pVQ                  JC's Restaurant
# 9            708  giCq1MmW-_S2tvNOAHvJcQ             Tarbell's The Tavern
# 10           725  HGc61UN2Gr9RGQXC6mXFNQ                   Swirl Wine Bar
# 11           811  aXsmmtepl0JZNcl3pkXqww         Sacks Sandwiches - Hardy
# ...

# %%
#Get the distribution of business ratings
star1=american_traditional_business['stars'].value_counts()
star1=star1.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star1.index, star1.values, alpha=0.8)
plt.title("Star Rating Distribution of American Traditional Business", fontsize=20)
plt.ylabel('Number of Businesses', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star1.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Get the distribution of business ratings
star2=american_new_business['stars'].value_counts()
star2=star2.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star2.index, star2.values, alpha=0.8)
plt.title("Star Rating Distribution of American New Business",fontsize=20)
plt.ylabel('Number of Businesses', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star2.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#read review
american_traditional_review = pd.read_csv('american_traditional_review.csv')
american_new_review = pd.read_csv('american_new_review.csv')

# %%
#Get the distribution of reviews ratings
star_review1=american_traditional_review['stars'].value_counts()
star_review1=star_review1.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star_review1.index, star_review1.values, alpha=0.8)
plt.title("Star Rating Distribution of American Traditional Business Review",fontsize=20)
plt.ylabel('Number of Reviews', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star_review1.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Get the distribution of reviews ratings
star_review2=american_new_review['stars'].value_counts()
star_review2=star_review2.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star_review2.index, star_review2.values, alpha=0.8)
plt.title("Star Rating Distribution of American New Business Review",fontsize=20)
plt.ylabel('Number of Reviews', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star_review2.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Global view of Yelp businesses

#basic basemap of the world
plt.figure(1, figsize=(15,6))
# use ortho projection for the globe type version
m1=Basemap(projection='ortho',lat_0=20,lon_0=-50)

#hex codes from google maps color pallete = http://www.color-hex.com/color-palette/9261
#add continents
m1.fillcontinents(color='#bbdaa4',lake_color='#4a80f5') 
#add the oceans
m1.drawmapboundary(fill_color='#4a80f5')                
#Draw the boundaries of the countires
m1.drawcountries(linewidth=0.1, color="black")

#Add the scatter points to indicate the locations of the businesses
mxy1 = m1(american_traditional_business["longitude"].tolist(), american_traditional_business["latitude"].tolist())
m1.scatter(mxy1[0], mxy1[1], s=2, c="orange", lw=0.5, alpha=1, zorder=5)
plt.title("World-wide Yelp American Traditional Business Distribution",fontsize=20)
plt.show()

# %%
#Global view of Yelp businesses

#basic basemap of the world
plt.figure(1, figsize=(15,6))
# use ortho projection for the globe type version
m2=Basemap(projection='ortho',lat_0=20,lon_0=-50)

#hex codes from google maps color pallete = http://www.color-hex.com/color-palette/9261
#add continents
m2.fillcontinents(color='#bbdaa4',lake_color='#4a80f5') 
#add the oceans
m2.drawmapboundary(fill_color='#4a80f5')                
#Draw the boundaries of the countires
m2.drawcountries(linewidth=0.1, color="black")

#Add the scatter points to indicate the locations of the businesses
mxy2 = m2(american_new_business["longitude"].tolist(), american_new_business["latitude"].tolist())
m2.scatter(mxy2[0], mxy2[1], s=2, c="orange", lw=0.5, alpha=1, zorder=5)
plt.title("World-wide Yelp American New Business Distribution",fontsize=20)
plt.show()

# %%
def json_get_length(path):
    with open(path, encoding="utf-8") as f:
        lines = f.readlines()
        return len(lines)

# %%
def json_to_df(path, l):
    with open(path, encoding="utf-8") as f:
        dic = {}
        for i in tqdm(range(l)):
            line = f.readline()
            dic_new = dict(json.loads(line))
            if i == 0:
                dic = dic_new
                for key in dic:
                    dic[key] = [dic[key]]
            else:
                for key in dic:
                    dic[key].append(dic_new[key])
        f.close()
        dic = pd.DataFrame(dic)
        return dic

# %%
#read business file
l_business=json_get_length('business.json')
business = json_to_df('business.json',l_business)
business.head()

# %%
#read review file
l_review=json_get_length('review.json')
review = json_to_df('review.json',l_review)
review.head()
# Out:
# 100%|██████████| 6685900/6685900 [05:13<00:00, 21338.62it/s]

# %%
unique_business_id = set(list(review['business_id']))

# %%
#find information only for these business
business = business[business['business_id'].isin(unique_business_id)]
business_categories=business['categories']

# %%
#restaurant business categories
business.index = range(len(business))
restaurant = []
categories_count = {}
for i in tqdm(range(len(business))):
    if business.loc[i, 'categories']:
        if "Restaurants" in business.loc[i, 'categories']:
            restaurant.append(i)
            curr = business.loc[i, 'categories'].split(',')
            for e in curr:
                categories_count[e] = categories_count.get(e, 0)+1
# Out:
# 100%|██████████| 192606/192606 [00:09<00:00, 19744.59it/s]

# %%
sorted_cat = sorted(categories_count.items(),key = operator.itemgetter(1))
sorted_cat=sorted_cat[::-1][1:20]
sorted_cat
# Out:
# [('Restaurants', 17948),
#  (' Food', 11956),
#  (' Nightlife', 7133),
#  (' Bars', 6888),
#  (' American (Traditional)', 5542),
#  (' Sandwiches', 5524),
#  (' Fast Food', 5320),
#  (' Pizza', 4658),
#  (' Breakfast & Brunch', 4231),
#  (' Burgers', 4138),
#  (' American (New)', 3790),
#  (' Italian', 3381),
#  (' Coffee & Tea', 3041),
#  (' Mexican', 3033),
#  (' Chinese', 2867),
#  ('Food', 2844),
#  (' Cafes', 2561),
#  (' Event Planning & Services', 2277),
#  ('Pizza', 2146)]

# %%
from pandas.core.frame import DataFrame
cat_df=DataFrame(sorted_cat)
dic = {'cat_name': cat_df[0], 'cat_count':cat_df[1]}
cat_df=DataFrame(dic)

# %%
plt.subplots(figsize=(8, 8))
labels=cat_df['cat_name']
cat_df['cat_count'].plot.bar( align='center', alpha=0.5)
y_pos = np.arange(len(labels))
#plt.yticks(y_pos, labels)
plt.xticks(y_pos, labels)
plt.xlabel('Restaurant Business Categories')
plt.ylabel('Categories Count')
plt.show()

# %%
#whole business categories
business.index = range(len(business))
whole_categories_count = {}
for i in tqdm(range(len(business))):
    if business.loc[i, 'categories']:
        curr = business.loc[i, 'categories'].split(',')
        for e in curr:
            whole_categories_count[e] = whole_categories_count.get(e, 0)+1
# Out:
# 100%|██████████| 192606/192606 [00:07<00:00, 24542.80it/s]

# %%
whole_sorted_cat = sorted(whole_categories_count.items(),key = operator.itemgetter(1))
whole_sorted_cat=whole_sorted_cat[::-1][0:20]
whole_sorted_cat
# Out:
# [(' Restaurants', 41423),
#  (' Shopping', 24086),
#  (' Food', 21966),
#  ('Restaurants', 17948),
#  (' Home Services', 14462),
#  (' Beauty & Spas', 13538),
#  (' Health & Medical', 12601),
#  (' Local Services', 10519),
#  (' Nightlife', 10382),
#  (' Bars', 9209),
#  (' Automotive', 9073),
#  (' Event Planning & Services', 8144),
#  ('Food', 8022),
#  ('Shopping', 7790),
#  (' Active Life', 7202),
#  (' Fashion', 6154),
#  ('Beauty & Spas', 5832),
#  (' American (Traditional)', 5542),
#  (' Sandwiches', 5524),
#  (' Coffee & Tea', 5344)]

# %%
from pandas.core.frame import DataFrame
whole_cat_df=DataFrame(whole_sorted_cat)
dic = {'cat_name': whole_cat_df[0], 'cat_count':whole_cat_df[1]}
whole_cat_df=DataFrame(dic)
# Out:
#                       cat_name  cat_count
# 0                  Restaurants      41423
# 1                     Shopping      24086
# 2                         Food      21966
# 3                  Restaurants      17948
# 4                Home Services      14462
# 5                Beauty & Spas      13538
# 6             Health & Medical      12601
# 7               Local Services      10519
# 8                    Nightlife      10382
# 9                         Bars       9209
# 10                  Automotive       9073
# 11   Event Planning & Services       8144
# 12                        Food       8022
# 13                    Shopping       7790
# 14                 Active Life       7202
# 15                     Fashion       6154
# 16               Beauty & Spas       5832
# 17      American (Traditional)       5542
# 18                  Sandwiches       5524
# 19                Coffee & Tea       5344

# %%
plt.subplots(figsize=(8, 8))
labels=whole_cat_df['cat_name']
whole_cat_df['cat_count'].plot.bar( align='center', alpha=0.5)
y_pos = np.arange(len(labels))
#plt.yticks(y_pos, labels)
plt.xticks(y_pos, labels)
plt.xlabel('Business Categories')
plt.ylabel('Categories Count')
plt.show()

# %%
#bars
bars_tip = pd.read_csv('bars_tip.csv')  
bars_tip
# Out:
#         Unnamed: 0                 user_id             business_id  \
# 0                0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1                2  jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 2                6  w8p4JW6-ERsbg8aB5wjEAg  0hudPyuCBlKg79OwKBw-eQ
# 3               11  NXXC2iU0o3tDVu6YNaW3Ww  oGASRzKGpuiP12ilQH_nKg
# 4               14  NEN5RFpZp7DE6K1PK2KZzg  Cni2l-VKG_pdospJ6xliXQ
# 5               24  lesnCKZUYH554j-EDZBlTw  7sPNbCx7vGAaH7SbNPZ6oA
# 6               38  CcJQAZfk6QkaBjPnKepLcg  vYn0gishV27DpfM_loZITQ
# 7               44  R_wlZO-jKFGEVJnSfWISqQ  Z15a7_8FQ82_baSJiqMoIw
# 8               51  330erZ8TCzA2eoexQMATBg  6sKaAF8WhWyyCjfZr2Rfsg
# 9               52  T1jicY-vxpCOTl5SIdVLxg  _sOni_t0FvAQuUDBEGe3Gg
# 10              65  AIHzJz0AvTq0FxCLtBhOZA  yNPh5SO-7wr8HPpVCDPbXQ
# 11              72  T9xfkjF1R0a_fIjZ-7Hofw  Mn6PbumS7GL2v3jPilTaeg
# 12              79  YB2SZbMgQHBOGOIsBK2Tkg  maIam6HyU4FB_sBIk9ippA
# ...

# %%
bars_review=pd.read_csv('bars_review.csv')  
bars_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 0                3  yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg
# 1               11  -I5umRTkhw15RqpKMl_o1Q  -mA3-1mN4JIEkqOtdbNXCQ
# 2               35  wOv7JiO0EGcJ61P2JcDS1g  en0xQXlvRk-ZtKlaW4I8eQ
# 3               36  RLbWoIri29BcQ8yjzsvQLQ  _o740mSNRhMNYuPjSJoPLg
# 4               52  Saae_VVf_v0fyNmB6Dc4kw  PttoI2Meg76KVB8JxjC5Xw
# 5               53  7Jy730ib54YKYgZRvcBNJg  ROsjOYL8Jwv-q78mNm69Hg
# 6               64  ASZha3MiQJghtt3n5OGIsA  Fyn9aNWs0Qcz6T-uIJal4w
# 7               67  XAm4_-lUxzF_Y449cWMHLQ  ABUt9wCHRsSpa8i7rtNAuQ
# 8               71  4PKiLkFTff9HK44QkOo6vA  vDlrf84X8yu-CZ-8isrOSw
# 9               72  QSe9EqmiImbguDVIraX_rg  II8eB5mYk200GW-m-wpsug
# 10              83  JYdhCDyR6lYfN2qnSspLlQ  6kEFHccntnYMF_7cdqCcKg
# 11              85  29S2A-Q8Vt4a-Z6St1dcWw  J6YedGZVdhagKKaIqgzIAw
# 12              94  LaSg1wlkosR6aSiuzxyo3A  9QoXklTk-Fl1Q1Cy8fCbdQ
# ...

# %%
bars_business=pd.read_csv('bars_business.csv')  
bars_business
# Out:
#       Unnamed: 0             business_id  \
# 0             12  5t3KVdMnFgAYmSl1wYLhmA
# 1             22  KWywu2tTEPWmR9JnBc0WyQ
# 2             25  tstimHoMcYbkSC4eBA1wEg
# 3             66  dQj5DLZjeDK3KFysh1SYOQ
# 4            113  7aLkFEBnL1LJmQdcuaovuQ
# 5            120  0lFAD4CuWcQVl9u3-lRaCQ
# 6            198  4n81G-pmC3rfhmaPsbwYKg
# 7            216  iwGhazq9eP51PSerTrMrwg
# 8            247  z3csSfd-UBMP1Gk6zHY_AA
# 9            248  3E0JDI0XMUoFztoEmX2D7w
# 10           251  a7zF4dDTeswXZGmohBDbJw
# 11           281  N1a_o-SGOWf2kdY2uRSs8g
# 12           294  hZj2HCiLae5-AxIp0im6lQ
# 13           355  iA9xu-6oOFynZQxO5qrauQ
# 14           424  mQkVFNSDpD4frPUMycVoWw
# 15           454  GiTv0gFXtYFQAzCXnPvepQ
# 16           485  3-aEgS7X2jrbxA7sA1nARw
# 17           513  ZBE-H_aUlicix_9vUGQPIQ
# 18           529  h_ypoQ2rmwX8UGSmohsGiQ
# 19           534  yGMCl0vYigshkXiZFIDTNw
# 20           584  RGK23CEkDfYHWtUbRhA-bQ
# 21           615  Lhsfy2uf8LyhMYgjbop7Sw
# ...

# %%
#
review_bad=list(bars_review['stars'])
review_bad=list(map(float, review_bad))
review_bad=list(map(int, review_bad))
bars_review['stars']=review_bad
bars_review =bars_review[bars_review ['stars']<3]

# %%
bars_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 1               52  Saae_VVf_v0fyNmB6Dc4kw  PttoI2Meg76KVB8JxjC5Xw
# 6              256  BOzcsr9s5foYKUmMu1Pjqg  -TMDrC66dvClx5Z7Hdzrfw
# 7              290  aMxFw47-dJtW45_GETNwrA  1690S3k0Myq111MM4OjESg
# 11             415  JDBddv-ypMMKf9VlzvX6fQ  nmYs0r8-hei7Yr49ycafJg
# 13             499  tketMNTsbOTlPyR6SNdDeg  SQmRvbWO7liODvGOUni17g
# 14             583  RO1CkfAEJA_PBrse6bHfsg  K4lrgtSKdFyRWeSaeXwQig
# 16             640  uNvd2Bzic2fVBh4EalsRJw  aYPj-ctL8zpeL5-Ny8KFng
# 17             650  o2KT5D8ZMi-nIXHB3s6zsw  F_OwlNnHoNeOQEAStcTQDA
# 21             706  EZc4yrQzIQD2xEX9w254qQ  KgmYVwUeMdHsrlVFRIIfIg
# 24             929  wBMfv_1DDSKc8qouCApUqA  2Be8v87CjxESlYpPLdsQfA
# 25             993  ZrQ6PqgZZOcaH8pDlil1ww  xtwoOTTOuZrXj4GQtsueuA
# 29            1101  JrrTV0W0I1ghblJYSTZYTw  SbpEMWghc9wXo-iv2ESXsg
# 33            1264  o6jzzvlWf-NhYzGnOstomw  qSoTmYMgajrUJx58neYNeg
# ...

# %%
img = Image.open('yelp.png')
img_array = np.array(img)
yelp_bad1= WordCloud(
    background_color='white',
    width=1200,
    height=400,
    mask=img_array)
yelp_bad1.generate(' '.join(bars_review['text'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(yelp_bad1)
plt.axis('off');

# %%
#Get the distribution of bars reviews ratings
star1=bars_review['stars'].value_counts()
star1=star1.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star1.index, star1.values, alpha=0.8)
plt.title("Star Rating Distribution of Bars Reviews",fontsize=20)
plt.ylabel('Number of Businesses', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star1.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
#Get the distribution of bars business ratings
star2=bars_business['stars'].value_counts()
star2=star2.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(star2.index, star2.values, alpha=0.8)
plt.title("Star Rating Distribution of Bars Business",fontsize=20)
plt.ylabel('Number of Reviews', fontsize=18)
plt.xlabel('Star Ratings ', fontsize=18)

#adding the text labels
rects = ax.patches
labels = star2.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')

plt.show()

# %%
bars_business
# Out:
#       Unnamed: 0             business_id  \
# 0             12  5t3KVdMnFgAYmSl1wYLhmA
# 1            198  4n81G-pmC3rfhmaPsbwYKg
# 2            247  z3csSfd-UBMP1Gk6zHY_AA
# 3            294  hZj2HCiLae5-AxIp0im6lQ
# 4            344  oqvh7TAJgyayxYwNM4PlZw
# 5            513  ZBE-H_aUlicix_9vUGQPIQ
# 6            608  0WBMEfqXQnEOAIkV-uCW6w
# 7            898  efxnaXEAWCeB1S-fv_Ri0Q
# 8            980  Es8M4aIZ_KKPb6oUtcdSqw
# 9           1130  VUbACJQR-_dVwyPYMFSodg
# 10          1191  iTzrTaw0UNTI76G9cstxRA
# 11          1251  u-IVGF-wGwvxuj3uKQW8qw
# 12          1549  qjPC-pjICixwWsambEosqQ
# 13          1661  eVvnRqb4GSJUfN5k2-9oOQ
# 14          1662  t_XpjR3_Cf7r9tj3w3vAbw
# 15          1780  c78Pat78fVUBFPXYeVvbaQ
# 16          1799  CikOhGCgZIRKnHGiinSluQ
# 17          1806  dQxowi8M1a0F6QFLzp8T7Q
# 18          1814  QvyG5fZ0mxo5yeLY8jabCA
# 19          1819  5_F4_jx2GT_jWVQWATc9DQ
# 20          1835  tdo6JvAKwmMAKU8T5jfORw
# 21          1977  vn-vRefiIb92Y7pniF6ypA
# ...

# %%
bars_business['attributes']
# Out:
# 0       {'BusinessParking': "{'garage': False, 'street...
# 1                                                     NaN
# 2       {'Caters': 'False', 'WiFi': "'free'", 'Ambienc...
# 3       {'Music': "{'dj': True, 'background_music': Fa...
# 4       {'RestaurantsPriceRange2': '1', 'HasTV': 'True...
# 5       {'BusinessAcceptsCreditCards': 'True', 'Alcoho...
# 6       {'RestaurantsPriceRange2': '1', 'RestaurantsGo...
# 7       {'BikeParking': 'True', 'BestNights': "{'monda...
# 8       {'RestaurantsPriceRange2': '2', 'WiFi': "u'pai...
# 9       {'RestaurantsAttire': "'casual'", 'GoodForKids...
# 10      {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 11      {'NoiseLevel': "'average'", 'Alcohol': "'full_...
# 12      {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 13      {'RestaurantsPriceRange2': '2', 'Ambience': "{...
# 14      {'WiFi': "'no'", 'HasTV': 'False', 'Restaurant...
# 15      {'Alcohol': "u'full_bar'", 'Caters': 'False', ...
# ...

# %%
#sandwiches
sandwiches_tip = pd.read_csv('sandwiches_tip.csv')  
sandwiches_review=pd.read_csv('sandwiches_review.csv')  
sandwiches_business=pd.read_csv('sandwiches_business.csv')
